# %%
import pandas as pd
import csv

# %%
file = open('lookup.csv','r',encoding='utf-8')

# %%
data = csv.reader(file,delimiter=',')

# %%
editor_dict = {}
for row in data:
    k = row[2]
    v = row[3]
    editor_dict[k] = v

# %%
editor_dict
# Out:
# {'Old Teubner Name': 'DLL Author Name',
#  'Álvares, Manuel, 1526-1583': '91777 : Alvares, Manuel, 1526-1583',
#  'Andresen, Georg, 1845-1929': '91778 : Andresen, Georg, 1845-',
#  'Baehrens, W. A. (Willem Adolf), 1885-1929': '91779 : Baehrens, W. A. (Willem Adolf), 1885-1929',
#  'Bauer, Ludwig, active 1883-1892': '91780 : Bauer, Ludwig, active 1883-1892',
#  'Bekker, Immanuel, 1785-1871': '91781 : Bekker, Immanuel, 1785-1871',
#  'Benndorf, Otto, 1838-1907': '91782 : Benndorf, Otto, 1838-1907',
#  'Benoist, Eugène, 1831-1887': '91783 : Benoist, Eugène, 1831-1887',
#  'Benseler, Gustav Eduard, 1806-1868': '91784 : Benseler, Gustav Eduard, 1806-1868',
#  'Bernays, Jacob, 1824-1881.': '91785 : Bernays, Jacob, 1824-1881',
#  'Bidez, Joseph, 1867-1945': '91786 : Bidez, Joseph, 1867-1945',
#  'Boenig, Hermann': '91787 : Boenig, Hermann, 1860-',
#  'Brandt, Paul, 1861-1932': '91788 : Brandt, Paul, 1861-1932',
# ...

# %%
df = pd.read_csv('teubners-filtered-20180930.csv')

# %%
df
# Out:
#      Index                                             Author  \
# 0        0                                   44546 : Apuleius
# 1        1                                   44546 : Apuleius
# 2        2                                   44546 : Apuleius
# 3        3                                   44546 : Apuleius
# 4        4                                   44546 : Apuleius
# 5        5                                                NaN
# 6        6                                 44653 : Censorinus
# 7        7              44757 : Eutropius, active 4th century
# 8        8              44757 : Eutropius, active 4th century
# 9        9              44757 : Eutropius, active 4th century
# 10      10  44793 : Catullus, Gaius Valerius; Priapea; 457...
# 11      11                                    45037 : Martial
# 12      12                           45078 : Nepos, Cornelius
# 13      13                    45218 : Victor, Sextus Aurelius
# ...

# %%
df2 = pd.DataFrame(df['Editor'].apply(lambda x: str(x).split(';')))

# %%
df2
# Out:
#                                                 Editor
# 0           [84185: Vliet, Joannes van der, 1847-1902]
# 1      [84091 : Helm, Rudolf Wilhelm Oskar, 1872-1966]
# 2           [84185: Vliet, Joannes van der, 1847-1902]
# 3      [84091 : Helm, Rudolf Wilhelm Oskar, 1872-1966]
# 4                                                [nan]
# 5    [84183 : Thomas, Paul, 1852-1937,  84091 : Hel...
# 6    [89602 : Hultsch, Fridericus (Friedrich Otto),...
# 7    [84053 : Dietsch, Heinrich Rudolf, 1814-1875, ...
# 8    [84053 : Dietsch, Heinrich Rudolf, 1814-1875, ...
# 9                                                [nan]
# 10                 [84127 : Müller, Lucian, 1836-1898]
# 11                           [Gilbert, Walther, 1851-]
# 12                                               [nan]
# 13                                  [Pichlmayr, Franz]
# 14                                               [nan]
# 15                                               [nan]
# ...

# %%
df3 = pd.DataFrame(df2['Editor'].values.tolist())

# %%
df3
# Out:
#                                                      0  \
# 0             84185: Vliet, Joannes van der, 1847-1902
# 1        84091 : Helm, Rudolf Wilhelm Oskar, 1872-1966
# 2             84185: Vliet, Joannes van der, 1847-1902
# 3        84091 : Helm, Rudolf Wilhelm Oskar, 1872-1966
# 4                                                  nan
# 5                      84183 : Thomas, Paul, 1852-1937
# 6    89602 : Hultsch, Fridericus (Friedrich Otto), ...
# 7          84053 : Dietsch, Heinrich Rudolf, 1814-1875
# 8          84053 : Dietsch, Heinrich Rudolf, 1814-1875
# 9                                                  nan
# 10                   84127 : Müller, Lucian, 1836-1898
# 11                             Gilbert, Walther, 1851-
# 12                                                 nan
# 13                                    Pichlmayr, Franz
# 14                                                 nan
# 15                                                 nan
# ...

# %%
df4 = df3.replace({'Álvares, Manuel, 1526-1583': '91777 : Alvares, Manuel, 1526-1583',
 'Andresen, Georg, 1845-1929': '91778 : Andresen, Georg, 1845-',
 'Baehrens, W. A. (Willem Adolf), 1885-1929': '91779 : Baehrens, W. A. (Willem Adolf), 1885-1929',
 'Bauer, Ludwig, active 1883-1892': '91780 : Bauer, Ludwig, active 1883-1892',
 'Bekker, Immanuel, 1785-1871': '91781 : Bekker, Immanuel, 1785-1871',
 'Benndorf, Otto, 1838-1907': '91782 : Benndorf, Otto, 1838-1907',
 'Benoist, Eugène, 1831-1887': '91783 : Benoist, Eugène, 1831-1887',
 'Benseler, Gustav Eduard, 1806-1868': '91784 : Benseler, Gustav Eduard, 1806-1868',
 'Bernays, Jacob, 1824-1881.': '91785 : Bernays, Jacob, 1824-1881',
 'Bidez, Joseph, 1867-1945': '91786 : Bidez, Joseph, 1867-1945',
 'Boenig, Hermann': '91787 : Boenig, Hermann, 1860-',
 'Brandt, Paul, 1861-1932': '91788 : Brandt, Paul, 1861-1932',
 'Breysig, Alfred August Bernhard, 1831-1902': '91789 : Breysig, Alfred August Bernhard, 1831-1901',
 'Brieger, Adolf, 1832-1912': '91790 : Brieger, Adolf, 1832-1912',
 'Brummer, Jacob': '91791 : Brummer, Jacob',
 'Chatelain, Émile, 1851-1933': '91792 : Chatelain, Emile, 1851-1933',
 'Claussen, Johannes Diederich Detlef,1849-1929': '91793 : Claussen, Johannes Diederich Detlef, 1849-1929',
 'Cumont, Franz, 1868-1947': '91794 : Cumont, Franz, 1868-1947',
 'Curtze, E. L. W. M. (Ernst Ludwig Wilhelm Maximilian), 1837-1903': '91795 : Curtze, E. L. W. M. (Ernst Ludwig Wilhelm Maximilian), 1837-1903',
 'Dederich, Andreas, 1804-1886': '91796 : Dederich, Andreas, 1804-',
 'Derz, Friedrich (1913-)': '91797 : Derz, Friedrich W.',
 'Deuerling, Andreas, 1838-1906': '91798 : Deuerling, Andreas, 1838-1906',
 'Deycks, Ferdinand, 1802-1867': '91799 : Deycks, Ferdinand, 1802-1867',
 'Dietrich, Waldemar, 1882-': '91800 : Dietrich, Waldemar',
 'Dindorf, Wilhelm, 1802-1883': '91801 : Dindorf, Wilhelm, 1802-1883',
 'Egenolff, Peter, 1851-1901': '91802 : Egenolff, Peter, 1851-1901',
 'Eyssenhardt, Franz, 1838-1901': '91803 : Eyssenhardt, Franz, 1838-1901',
 'Flach, Hans': '91804 : Flach Hans, 1845-1895',
 'Foerster, Richard, 1843-1922': '91805 : Foerster, Richard, 1843-1922',
 'Fox, Wilhelm, 1833-1925': '91806 : Fox, Wilhelm, 1833-1925',
 'Frey, Joseph, 1834-1910': '91807 : Frey, Joseph, 1834-1910',
 'Gast, Ernst-Reinhard 1842-1904': '91808 : Gast, Ernst-Reinhard, 1842-1904',
 'Georges, Heinrich, 1852-1921': '91809 : Georges, Heinrich, 1852-1921',
 'Gilbert, Walther, 1851-': '91810 : Gilbert, Walther, 1851-',
 'Giussani, Carlo, 1840-1900': '91811 : Giussani, Carlo, 1840-1900',
 'Gneist, Rudolph, 1816-1895': '91812 : Gneist, Rudolph, 1816-1895',
 'Güthling, Otto, 1853-1931': '91813 : Güthling, Otto, 1853-1931',
 'Häckermann, Adolf, 1819-': '91814 : Häckermann, Adolf 1819-',
 'Hagen, Hermann, 1844-1898': '91815 : Hagen, Hermann, 1844-1898',
 'Harster, Wilhelm, 1846-1901': '91816 : Harster, Wilhelm, 1846-1901',
 'Hedicke, Edmund': '91817 : Hedicke, Edmund, 1840-',
 'Helmreich, Georg, 1849-1921': '91818 : Helmreich, Georg, 1849-1921',
 'Heraeus, Carl (Karl Jesaias), 1818-1891': '91819 : Heraeus, Carl Jesaias, 1818-1891',
 'Heraeus, W. (Wilhelm), 1862-1938': '91820 : Heraeus, W. (Wilhelm), 1862-1938',
 'Herding, Wilhelm': '91821 : Herding, Wilhelm',
 'Hertlein, Friedrich Karl Gottlob, 1803-1880': '91822 : Hertlein, Friedrich Karl Gottlob, 1803-1880',
 'Hildebrandt, Paul': '91824 : Hildebrandt, Paul, 18..-19..',
 'Hofmeister, Adolf, 1883-1956': '91825 : Hofmeister, Adolf, 1883-1956',
 'Hohl, Ernst, 1886-1957': '91826 : Hohl, Ernst, 1886-1957',
 'Huemer, Johann, 1849-1915': '91827 : Huemer, Johann, 1849-1915',
 'Inama, Vigilio, 1835-1912': '91828 : Inama, Vigilio, 1835-1912',
 'Jacobitz, Karl': '91829 : Jacobitz, Karl, 1807-1875',
 'Jahn, Johann Christian': '91830 : Jahn, Johann Christian, 1797-1847',
 'Janell, Walther, 1877-1932': '91831 : Janell, Walther, 1877-1932',
 'Canabutzes, Joannes': '91832 : Johannes Canabutius, ca. 15. Jh.',
 'Kaiser, Paul, 1852-1917': '91833 : Kaiser, Paul, 1852-1917',
 'Keller, Otto, 1838-1927': '91834 : Keller, Otto, 1838-1927',
 'Klotz, Alfred, 1874-1956': '91835 : Klotz, Alfred, 1874-1956',
 'Knoellinger, Hermann, 1883-1914': '91836 : Knoellinger, Hermann, 1883-1914',
 'Kroll, Wilhelm': '91837 : Kroll, Wilhelm, 1869-1939',
 'Krueger, Paul, 1840-1926': '91838 : Krueger, Paul, 1840-1926',
 'Krüger, G. T. A. (Georg Theodor August), 1793-1873': '91839 : Krüger, G. T. A. (Georg Theodor August), 1793-1873',
 'Krüger, Gustav, 1837-1912': '91840 : Krüger, Gustav, 1837-1912',
 'Krumbiegel, Richard, 1867-': '91841 : Krumbiegel, Richard, 1867-',
 'Künstle, Karl, 1859-1932': '91842 : Künstle, Karl, 1859-1932',
 'Kuun, Géza, 1838-1905': '91843 : Kuun, Géza, 1838-1905',
 'La Sale, Antoine de, 1385?-1461?': '91844 : La Sale, Antoine de, 1385?-1461?',
 'Loewe, Gustav, 1852-1883': '91845 : Löwe, Gustav, 1852-1883',
 'Lüdtke, W. (Willy), 1875-': '91846 : Lüdtke, W. (Willy), 1875-',
 'Magnus, Hugo, 1851-1924': '91847 : Magnus, Hugo, 1851-1924',
 'Manitius, Max, 1858-1933': '91848 : Manitius, Max, 1858-1933',
 'Meissner, Carl, 1830-1900': '91849 : Meissner, Carl, 1830-',
 'Mekler, S. (Siegfried), 1852-1912': '91850 : Mekler, S. (Siegfried), 1852-1912',
 'Menge, Heinrich': '91851 : Menge, Hermann, 1841-1916',
 'Merzdorf, J. F. L. Theodor (Johann Friedrich Ludwig Theodor), 1812-1877': '91852 : Merzdorf, J. F. L. Theodor (Johann Friedrich Ludwig Theodor), 1812-1877',
 'Meurer, Wolfgang, 1513-1585': '91853 : Meurer, Wolfgang, 1513-1585',
 'Meyer, Wilhelm, 1845-1917.': '91854 : Meyer, Wilhelm, 1845-1917',
 'Monet, Pascal': '91855 : Monet, Pascal',
 'Moser, Georg Heinrich, 1780-1858': '91856 : Moser, Georg Heinrich, 1780-1858',
 'Mueller, Otto, 1833-': '91857 : Mueller, Otto, 1833-',
 'Nauck, August, 1822-1892': '91858 : Nauck, August, 1822-1892',
 'Nissen, Theodor Karl Johannes, 1873-': '91859 : Nissen, Theodor, 1873-1946',
 'Onions, John Henry, 1852-1889': '91860 : Onions, John Henry, 1852-1889',
 'Owen, S. G. (Sidney George), 1858-1940': '91861 : Owen, S. G. (Sidney George), 1858-1940',
 'Peter, Hermann, 1837-1914': '91862 : Peter, Hermann, 1837-1914',
 'Peterson, William, 1856-1921': '91863 : Peterson, William, 1856-1921',
 'Pichlmayr, Franz': '91864 : Pichlmayr, Franz, 1861-1926',
 'Polle, Friedrich, 1830-1902': '91865 : Polle, Friedrich, 1830-1902',
 'Rabe, Hugo': '91866 : Rabe, Hugo, 1867-1932',
 'Radermacher, Ludwig, 1867-1952': '91867 : Radermacher, Ludwig, 1867-1952',
 'Ramorino, F. (Felice), 1852-1929': '91868 : Ramorino, F. (Felice), 1852-1929',
 'Ranke, Friedrich, 1882-1950': '91869 : Ranke, Friedrich, 1882-1950',
 'Reisch, Emil, 1863-1933': '91870 : Reisch, Emil, 1863-1933',
 'Ritter, Constantin, 1859-1936': '91871 : Ritter, Constantin, 1859-1936',
 'Röhl, Hermann, 1851-1923': '91872 : Röhl, Hermann, 1851-1923',
 'Romarino, Felice': '91873 : Romarino, Felice',
 'Scheibe, Karl Friedrich, 1812-1869': '91874 : Scheibe, Karl Friedrich, 1812-1869',
 'Schermann, Theodor, 1878-1922': '91875 : Schermann, Theodor, 1878-1922',
 'Schiche, Theodor': '91876 : Schiche, Theodor',
 'Schlee, Friedrich H., 1854-1913': '91877 : Schlee, Friedrich, 1854-1913',
 'Schmid, Theodor, 1798-1877': '91878 : Schmid, Theodor, 1798-1877',
 'Schmidt, Wilhelm, 1862-1905': '91879 : Schmidt, Wilhelm, 1862-1905',
 'Schömann, Georg Friedrich, 1793-1879': '91880 : Schömann, Georg Friedrich, 1793-1879',
 'Schubart, Wilhelm, 1873-1960': '91881 : Schubart, Wilhelm, 1873-1960',
 'Siebelis, Johannes, 1817-1867': '91882 : Siebelis, Johannes, 1817-1867',
 'Sittl, Karl, 1862-1899': '91883 : Sittl, Karl, 1862-1899',
 'Swoboda, Antonius, 1865-1928': '91884 : Swoboda, Antonius, 1865-1928',
 'Thulin, Carl, 1871-1921': '91885 : Thulin, Carl, 1871-1921',
 'Türk, Gustav': '91886 : Türk, Gustav, 1870-1914',
 'Usener, Hermann, 1834-1905': '91887 : Usener, Hermann, 1834-1905',
 'Vogel, Theodor, 1836-1912': '91888 : Vogel, Theodor, 1836-1912',
 'Vollgraff, J.C. (Johann Christoph), 1848-1920': '91889 : Vollgraff, J. C. (Johann Christoph), 1848-1920',
 'Waltzing, Jean-Pierre, 1857-1929': '91890 : Waltzing, Jean Pierre, 1857-1929',
 'Weber, Ernestus': '91891 : Weber, Ernst, 1873',
 'Weil, Henri, 1818-1909': '91892 : Weil, Henri, 1818-1909',
 'Wesenberg, Albert Sadolin, 1804-1876': '91893 : Wesenberg, Albert Sadolin, 1804-1876',
 'Zangemeister, Karl Friedrich Wilhelm, 1837-1902': '91894 : Zangemeister, Karl Friedrich Wilhelm, 1837-1902'})

# %%
df4
# Out:
#                                                      0  \
# 0             84185: Vliet, Joannes van der, 1847-1902
# 1        84091 : Helm, Rudolf Wilhelm Oskar, 1872-1966
# 2             84185: Vliet, Joannes van der, 1847-1902
# 3        84091 : Helm, Rudolf Wilhelm Oskar, 1872-1966
# 4                                                  nan
# 5                      84183 : Thomas, Paul, 1852-1937
# 6    89602 : Hultsch, Fridericus (Friedrich Otto), ...
# 7          84053 : Dietsch, Heinrich Rudolf, 1814-1875
# 8          84053 : Dietsch, Heinrich Rudolf, 1814-1875
# 9                                                  nan
# 10                   84127 : Müller, Lucian, 1836-1898
# 11                     91810 : Gilbert, Walther, 1851-
# 12                                                 nan
# 13                 91864 : Pichlmayr, Franz, 1861-1926
# 14                                                 nan
# 15                                                 nan
# ...

# %%
df4.to_csv('replaced_editors.csv')

# %%
editors_to_combine = csv.reader(open('replaced_editors.csv','r',encoding='utf-8'))

# %%
editors_to_combine

# %%
import codecs
with open('combined.csv','a',encoding='utf-8') as f:
    w = csv.writer(f)
    for row in editors_to_combine:
        del row[0]
        editors = [i for i in row if i is not '']
        editor_string = ';'.join(editors)
        w.writerow([editor_string])
