# %%
import pandas as pd

# %%
df = pd.read_csv('Teubners-Hathi.csv')

# %%
df
# Out:
#                                                 Author  \
# 0                                     44546 : Apuleius
# 1                                     44546 : Apuleius
# 2                                     44546 : Apuleius
# 3                                     44546 : Apuleius
# 4                                     44546 : Apuleius
# 5                                                  NaN
# 6                                   44653 : Censorinus
# 7                44757 : Eutropius, active 4th century
# 8                44757 : Eutropius, active 4th century
# 9                44757 : Eutropius, active 4th century
# 10   44793 : Catullus, Gaius Valerius; Priapea; 457...
# 11                                     45037 : Martial
# 12                            45078 : Nepos, Cornelius
# 13                     45218 : Victor, Sextus Aurelius
# 14                                        45254 : Livy
# 15                            45338 : Pliny, the Elder
# ...

# %%
df.to_csv('teubners-indexed.csv')
